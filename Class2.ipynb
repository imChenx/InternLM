# %% [markdown]
# # InternLM 实战营第二期笔记Class2 作业

# %% [markdown]
# ## 作业一、使用 InternLM2-Chat-1.8B 模型生成 300 字的小故事
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 作业二、熟悉 huggingface 下载功能，使用 huggingface_hub python 包，下载 InternLM2-Chat-7B 的 config.json 文件到本地（需截图下载过程）
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 作业三、完成 浦语·灵笔2 的 图文创作 及 视觉问答 部署（需截图）
#
# ### 图文创作
#
# ![image.png](attachment:image.png)
#
# ### 视觉问答
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 作业四、完成 Lagent 工具调用 数据分析 Demo 部署（需截图）
#
# ![image-2.png](attachment:image-2.png)
